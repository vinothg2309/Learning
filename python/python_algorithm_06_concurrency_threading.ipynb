# %% [markdown]
# # Concurrency & Parallelism — Threading Patterns

# %% [markdown]
# Adobe Interview Prep | 14 YOE

# %% [markdown]
# Covers:
#
#   1.  GIL — why threads for I/O, processes for CPU
#
#   2.  Thread lifecycle, daemon threads
#
#   3.  Race condition demo → fixed with Lock
#
#   4.  RLock (re-entrant lock)
#
#   5.  Semaphore — bounded concurrency (connection pool)
#
#   6.  Event — one-shot signal between threads
#
#   7.  Condition — wait / notify (producer-consumer)
#
#   8.  Barrier — rendezvous point
#
#   9.  Thread-safe bounded queue (Producer-Consumer full solution)
#
#   10. ThreadPoolExecutor — fan-out / fan-in pattern
#
#   11. Thread-local storage
#
#   12. Dining Philosophers (deadlock → solution)

# %% [markdown]
# See the original 06_concurrency_threading.ipynb notebook for full implementation with doctests, demos, and working examples.
