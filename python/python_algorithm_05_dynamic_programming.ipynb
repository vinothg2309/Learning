# %% [markdown]
# # Dynamic Programming — Senior Interview Patterns

# %% [markdown]
# Adobe Interview Prep | 14 YOE

# %% [markdown]
# Covers:
#
#   1.  Fibonacci / Climbing Stairs (1-D DP)
#
#   2.  House Robber I & II
#
#   3.  Longest Increasing Subsequence (LIS) — O(n²) & O(n log n)
#
#   4.  Coin Change — min coins, number of ways
#
#   5.  0/1 Knapsack & Unbounded Knapsack
#
#   6.  Longest Common Subsequence (LCS) & Edit Distance
#
#   7.  Partition Equal Subset Sum (subset-sum)
#
#   8.  Matrix DP — unique paths, minimum path sum
#
#   9.  Palindrome DP — longest palindromic substring, minimum cuts
#
#   10. Interval DP — burst balloons, matrix chain multiplication

# %% [markdown]
# See the original 05_dynamic_programming.ipynb notebook for full implementation with doctests, demos, and working examples.
