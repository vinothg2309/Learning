# %% [markdown]
# # Trees, Heaps & Tries — Senior Interview Patterns

# %% [markdown]
# Adobe Interview Prep | 14 YOE

# %% [markdown]
# Covers:
#
#   1.  Binary Tree — traversals (iterative + recursive)
#
#   2.  Binary Search Tree — insert, search, validate, kth smallest
#
#   3.  Lowest Common Ancestor (BST & general BT)
#
#   4.  Level-order (BFS) — zigzag, right side view
#
#   5.  Path problems — root-to-leaf sum, max path sum
#
#   6.  Serialize / Deserialize Binary Tree
#
#   7.  Heap — kth largest, top-k frequent elements
#
#   8.  Trie — insert, search, startsWith, word search

# %% [markdown]
# See the original 03_trees_heaps_tries.ipynb notebook for full implementation with doctests, demos, and working examples.
